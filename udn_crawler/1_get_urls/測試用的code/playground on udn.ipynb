# %%
#-*- coding: utf-8 -*-
#using python3


from selenium import webdriver
import time, re
from bs4 import BeautifulSoup
from time import sleep


chrome_path = ".\chromedriver.exe" #chromedriver.exe執行檔所存在的路徑
driver = webdriver.Chrome(chrome_path)

driver.implicitly_wait(10)

driver.get('https://udn.com/news/breaknews/1')

# %%
for i in range(200):
#    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    driver.execute_script('window.scrollTo(0,'+str(i*100)+')')
    sleep(0.1)
    
driver.find_element_by_link_text('看更多內容').click()


for i in range(200):
#    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    driver.execute_script('window.scrollTo(0,'+str(i*100)+')')
    sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-83db7b144f5e> in <module>()
#       4     sleep(0.1)
#       5
# ----> 6 driver.find_element_by_link_text('看更多內容').click()
#       7
#       8
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
for i in range(10):
    print("hihi")
    #driver.find_element_by_link_text('看更多內容').click()
    #sleep(0.1)
# Out:
# hihi
# hihi
# hihi
# hihi
# hihi
# hihi
# hihi
# hihi
# hihi
# hihi

# %%
for i in range(200):
#    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    driver.execute_script('window.scrollTo(0,'+str(i*100)+')')
    sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-079bd6e6f161> in <module>()
#       3 #    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
#       4     driver.execute_script('window.scrollTo(0,'+str(i*100)+')')
# ----> 5     sleep(0.1)
#
# KeyboardInterrupt:

# %%
print(driver.execute_script("return document.title"))
print(type(driver.execute_script("return document.title")))

print(driver.execute_script("return document.body.scrollHeight"))
print(type(driver.execute_script("return document.body.scrollHeight")))
# Out:
# 即時 | 聯合新聞網
# <class 'str'>
# 7662
# <class 'int'>

# %%
soup = BeautifulSoup(driver.page_source)
# Out:
# C:\Users\tony\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\tony\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print(soup.select('.area_body')[1].select('h2 a'))
#中括號內部的元素個數為class .area_body有多少div的格子的數目
# Out:
# [<a class="" href="/news/story/7005/3323638?from=udn-ch1_breaknews-1-0-news" target="">羽球／單項籤表出爐 小戴可能再碰何冰嬌</a>, <a class="" href="/news/story/6656/3323636?from=udn-ch1_breaknews-1-0-news" target="">影／台薩斷交 藍警告:中美北三角恐出現骨牌效應</a>, <a class="" href="/news/story/6656/3323629?from=udn-ch1_breaknews-1-0-news" target="">勉失親兒少 魏明谷：我15歲喪母，曾擔心爸爸也死掉</a>, <a class="" href="/news/story/7266/3323627?from=udn-ch1_breaknews-1-0-news" target="">柴油車遍地烽火 環署：公布攔查地點、專案輔導一期車</a>, <a class="" href="/news/story/7266/3323619?from=udn-ch1_breaknews-1-0-news" target="">香港出現登革熱疫情　赴黃大仙、長洲地區旅遊要當心</a>, <a class="" href="/news/story/6999/3323602?from=udn-ch1_breaknews-1-0-news" target="">MLB／今日戰績表 洋基延長賽勝馬林魚拉出4連勝</a>, <a class="" href="/news/story/10930/3323611?from=udn-ch1_breaknews-1-0-news" target="">砲擊操演設噪音監測？ 軍方：評估睦鄰經費用</a>, <a class="sp" href="/news/story/12429/3323609?from=udn-ch1_breaknews-1-0-news" target="">台薩斷交 蔡總統：中國企圖影響國內政局和選舉結果</a>, <a class="" href="/news/story/6999/3323485?from=udn-ch1_breaknews-1-0-ne
# ...

# %%
for block in soup.select('.area_body')[1].select('h2 a'):
    print(block.text)
    print(block['href'])
    print('\n\n')
# Out:
# 羽球／單項籤表出爐 小戴可能再碰何冰嬌
# /news/story/7005/3323638?from=udn-ch1_breaknews-1-0-news
#
#
#
# 影／台薩斷交 藍警告:中美北三角恐出現骨牌效應
# /news/story/6656/3323636?from=udn-ch1_breaknews-1-0-news
#
#
#
# 勉失親兒少 魏明谷：我15歲喪母，曾擔心爸爸也死掉
# /news/story/6656/3323629?from=udn-ch1_breaknews-1-0-news
#
#
#
# 柴油車遍地烽火 環署：公布攔查地點、專案輔導一期車
# /news/story/7266/3323627?from=udn-ch1_breaknews-1-0-news
#
#
#
# 香港出現登革熱疫情　赴黃大仙、長洲地區旅遊要當心
# /news/story/7266/3323619?from=udn-ch1_breaknews-1-0-news
#
#
#
# MLB／今日戰績表 洋基延長賽勝馬林魚拉出4連勝
# /news/story/6999/3323602?from=udn-ch1_breaknews-1-0-news
#
#
#
# 砲擊操演設噪音監測？ 軍方：評估睦鄰經費用
# /news/story/10930/3323611?from=udn-ch1_breaknews-1-0-news
#
#
#
# 台薩斷交 蔡總統：中國企圖影響國內政局和選舉結果
# /news/story/12429/3323609?from=udn-ch1_breaknews-1-0-news
#
#
#
# MLB／查普曼左膝不適提前退場 洋基傷兵潮來襲
# /news/story/6999/3323485?from=udn-ch1_breaknews-1-0-news
#
#
#
# 吳敦義訪養殖業 漁民：沒虱目魚契作 漁民尚可憐
# /news/story/10958/3323603?from=udn-ch1_breaknews-1-0-news
#
#
#
# 來台半世紀 丁松青今年終於能「選縣長」了
# /news/story/7324/3323600?from=udn-ch1_breaknews-1-0-news
#
#
# ...

# %%
# ?print("lkj")
