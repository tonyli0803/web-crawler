# %%
#經濟日報

import scrapy
import requests
from bs4 import BeautifulSoup
from lxml import html
from argparse import ArgumentParser
import datetime

from lxml import etree
import re

# %% [raw]
# ###################################
# ########判斷要不要更新資料#########
# ###################################
#
# ###上一次開始爬的新聞的相關資料
# date_last_time = ''
# time_last_time = ''
# url__last_time  = ''
# with open("ltn_news_timestamp.txt") as f:
#     tmp = []
#     for i in f.readlines():
#         tmp.append(i.strip('\n'))
#     if len(tmp)>0:
#         date_last_time = tmp[1].split('/')[-3]
#         time_last_time = tmp[0]
#         url__last_time = tmp[1]
#     else:
#         date_last_time = ""
#         time_last_time = ""
#         url__last_time = ""
#     #print(date_last_time,time_last_time,url__last_time)

# %%
now = datetime.datetime.now()
today = now.strftime("%Y-%m-%d ")
#print(today)

input_url = "https://money.udn.com/money/breaknews/1001/0/"
stop = False

links = []
timestamp = []

stop = False
cnt = 0

# %%
for i in range(1,15):
    try:
        # search each url in each page!!!
        print("page %d"%i)
        res = BeautifulSoup(requests.get(input_url+str(i)).text)


        for news in res.select('.area_body')[0].select('tr')[1:]:
            #print(news)
            #print('-----\n')

            #print(news.select('td'))
            #print('---------\n')




            #time = news.select('a')[0].select('time')[0].text
            title = news.select('td')[0].select('a')[0].text
            url = news.select('td')[0].select('a')[0]['href']



            #這邊因為及實新聞的那個頁面(EX "https://money.udn.com/money/breaknews/1001/0/1")並沒有年份資訊
            #所以去他的新聞內文的地方拿年份資訊
            date = etree.HTML(requests.get(url).text).xpath('//*[@id="shareBar"]/div[2]/div/span/text()')[0]


            #print("--------\n")
            #print(date,"    ",len(date))
            print(title)
            print(url)
            #print("--------\n")

            ###判斷要不要從第一頁第一個項目開始爬

            #print( time,time_last_time,  time > time_last_time ,date == date_last_time and time_last_time < time)

            '''
            if date < date_last_time:
                print("The data is up to date!!!!\nUpdate %d data this time"%cnt)
                stop = True
                break
            elif date == date_last_time and time < time_last_time:
                print("The data is up to date!!!!\nUpdate %d data this time"%cnt)
                stop = True
                break
            elif date == date_last_time and time == time_last_time and url == url__last_time:
                print("The data is up to date!!!!\nUpdate %d data this time"%cnt)
                stop = True
                break
            #爬了多少筆資料的counter
            cnt = cnt + 1


            if args.filter != "":
                if date <= args.filter:
                    stop = True

                    break

            links.append(url)

            print("----------------\nScapying news in")
            print(date+"  "+time)
            print(url)

            ###記錄這次的是從哪一個新聞開始爬起
            if len(timestamp) == 0 : 
                timestamp.append(time)
                timestamp.append(url)

            #這是跑到該網站裡面取標題，如果加這個會慢一些
            #tmp_res = BeautifulSoup(requests.get(tmp).text)
            #print(tmp_res.select('h1')[0].text)
            '''


        if stop == True:
            break
    except Exception as e:
        print(e)
        
    if len(res.select('.area_body')[0].select('tr')) == 1:
        break;
    
    
    print("-*-*-*-*-*-*-*-*-*-*--*-**-*--*--*-*-*")
# Out:
# page 8
# C:\Users\tony\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\tony\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#
a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 12:13</td>
# <td align="right" class="only_1280">79</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334473" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334457">賞鯨大驚喜！座頭鯨超近距離躍出水面<span class="mv"></span></a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 12:07</td>
# <td align="right" class="only_1280">596</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334457" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334448">屏北鄉鎮淹水封路多 網友暖心指引回家路</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 12:00</td>
# <td align="right" class="only_1280">224</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334448" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334449">躍升職訓國際舞台 勞部和APEC合作開專班</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 12:00</td>
# <td align="right" class="only_1280">48</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334449" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334450">台農業青年大使訪馬來西亞 促進農業交流</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 12:00</td>
# <td align="right" class="only_1280">28</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334450" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334438">日本第一連鎖炸牛排「京都勝牛」10月在台開幕</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:57</td>
# <td align="right" class="only_1280">2159</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334438" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334434">暴力電玩誘發槍枝暴力 美學界爭論</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:54</td>
# <td align="right" class="only_1280">269</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334434" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334430">高雄後勁溪水位暴漲 警方封便橋<span class="mv"></span></a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:53</td>
# <td align="right" class="only_1280">6543</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334430" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334431">同名同姓搞烏龍！澳洲達頓忙逼宮 美國達頓無辜爆紅</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:52</td>
# <td align="right" class="only_1280">1118</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334431" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334427">中國正建造價值人民幣10億超導計算機 </a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:49</td>
# <td align="right" class="only_1280">2977</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334427" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334415">美墨NAFTA談判達協議 關鍵重點一覽</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:45</td>
# <td align="right" class="only_1280">49</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334415" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3334416">達邦蛋白29日起開放競拍 底價18.18元</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/28 11:45</td>
# <td align="right" class="only_1280">71</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3334416" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a class="sp" href="https://money.udn.com/money/story/5641/3333435">絕地大反攻 被動元件股有多強</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/27 20:21</td>
# <td align="right" class="only_1280">12594</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3333435" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>, <tr>
# <td>
# <a href="https://money.udn.com/money/story/5641/3326109">持續更新／南部豪雨 27日全台停班停課看這裡</a>
# </td>
# <td align="center" class="only_web">即時</td>
# <td align="right" class="only_web">08/27 07:20</td>
# <td align="right" class="only_1280">142122</td>
# <td class="only_1280">
# <div class="fb-like" data-action="like" data-href="https://money.udn.com/money/story/5641/3326109" data-layout="button_count" data-share="false" data-show-faces="false" data-width="120"></div>
# </td>
# </tr>]
# -*-*-*-*-*-*-*-*-*-*--*-**-*--*--*-*-*
# page 9
# [<tr>
# <th>標題</th>
# <th align="center" class="only_web" width="80">類別</th>
# <th class="only_web" width="80">出版時間</th>
# <th align="right" class="only_1280" width="80">瀏覽數</th>
# <th class="only_1280" width="100">分享數</th>
# </tr>]

# %%
#存下這次的url記錄
#包括最新的url 其時間為何，以及有哪些URL等一下要爬
if len(links)>0:

    with open("apple_news_links.txt",'w') as f:
        for i in links:
            f.write(i)
            f.write('\n')

    with open("apple_news_timestamp.txt",'w') as f:
        for i in timestamp:
            f.write(i)
            f.write('\n')
    #exit(0)
else:
    #exit(1)
# Out:
#   File "<ipython-input-77-21fa782bd1dd>", line 16
#     #exit(1)
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
from lxml import etree
import re

res = requests.get("http://news.ltn.com.tw/news/world/breakingnews/2533627").text

#test xpath
selector = etree.HTML(res)
#抓取新聞的類別  
news_class = selector.xpath('/html/body/div[3]/section/div[3]/a[3]')
print(news_class[0].text)
# Out:
# 國際
